# %%
# %matplotlib inline

# help('modules')

import openbb_terminal
print(dir(openbb_terminal))
print(openbb_terminal.__path__)
print(openbb_terminal.__name__)
print("   ")
import sys
sys.path.append("Portfolio")
from Portfolio import *

# product_list = ["SVXY","QQQ","SPY","MSFT","TSM","PDD","AMD","CVX","XOM","TQQQ","BILI","NVDA","BABA"]

# hang seng tech index 
# KTEC, EWH
# holding_list = ["SVXY"],

#other idea is to compare tech/borad market 
# simulator = Portfolio(total_balance = 100000, underlying = None,holding_list = ["SVXY","VIXY"], indices = ["^VVIX"], data_start_date = "2012-01-01", sim_start_date = "2015-09-01" )
simulator = Portfolio(total_balance = 100000, underlying = "QQQ",holding_list = ["SVXY"],  data_start_date = "2012-01-01", sim_start_date = "2015-09-01" )
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', 'base_helpers', 'common', 'config_plot', 'config_terminal', 'core', 'cryptocurrency', 'decorators', 'economy', 'etf', 'feature_flags', 'forex', 'helper_classes', 'helper_funcs', 'loggers', 'portfolio', 'reports', 'rich_config', 'sdk', 'stocks', 'terminal_helper', 'thought_of_the_day']
# ['/home/will/.local/lib/python3.8/site-packages/openbb_terminal']
# openbb_terminal
#
# Retriving Data for Following products ['MSFT', 'AAPL', 'AMZN', 'NVDA', 'GOOGL', 'GOOG', 'META', 'TSLA', 'AVGO', 'PEP', 'COST', 'CSCO', 'TMUS', 'CMCSA', 'AMD', 'ADBE', 'NFLX', 'TXN', 'HON', 'SBUX', 'INTU', 'AMGN', 'INTC', 'QCOM', 'ISRG', 'AMAT', 'MDLZ', 'BKNG', 'GILD', 'ADI', 'ADP', 'VRTX', 'REGN', 'LRCX', 'FISV', 'MU', 'PYPL', 'MELI', 'CSX', 'MNST', 'ATVI', 'ASML', 'ORLY', 'PANW', 'KLAC', 'SNPS', 'CDNS', 'MAR', 'FTNT', 'CHTR', 'MRNA', 'KHC', 'CTAS', 'DXCM', 'LULU', 'KDP', 'AZN', 'AEP', 'NXPI', 'ABNB', 'BIIB', 'ADSK', 'MCHP', 'IDXX', 'PDD', 'CPRT', 'EXC', 'PAYX', 'WDAY', 'PCAR', 'MRVL', 'XEL', 'SGEN', 'ROST', 'DLTR', 'EA', 'VRSK', 'ODFL', 'CTSH', 'ILMN', 'FAST', 'CSGP', 'WBD', 'GFS', 'CRWD', 'BKR', 'WBA', 'DDOG', 'CEG', 'ANSS', 'EBAY', 'FANG', 'ENPH', 'ALGN', 'TEAM', 'JD', 'ZS', 'ZM', 'SIRI', 'LCID', 'RIVN', 'SVXY']
#
# MSFT, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# AAPL, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# AMZN, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# NVDA, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# GOOGL, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# GOOG, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# META, start 2012-05-18 , end 2023-03-31 total 2735 records
#
# TSLA, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# AVGO, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# PEP, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# COST, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# CSCO, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# TMUS, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# CMCSA, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# AMD, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# ADBE, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# NFLX, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# TXN, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# HON, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# SBUX, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# INTU, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# AMGN, start 2012-01-03 , end 2023-03-31 total 2829 records
#
# INTC, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# QCOM, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# ISRG, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# AMAT, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# MDLZ, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# BKNG, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# GILD, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# ADI, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# ADP, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# VRTX, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# REGN, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# LRCX, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# FISV, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# MU, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# PYPL, start 2015-07-06 , end 2023-03-31 total 1950 records
#
# MELI, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# CSX, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# MNST, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# ATVI, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# ASML, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# ORLY, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# PANW, start 2012-07-20 , end 2023-03-31 total 2692 records
#
# KLAC, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# SNPS, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# CDNS, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# MAR, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# FTNT, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# CHTR, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# MRNA, start 2018-12-07 , end 2023-03-31 total 1086 records
#
# KHC, start 2015-07-06 , end 2023-03-31 total 1950 records
#
# CTAS, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# DXCM, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# LULU, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# KDP, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# AZN, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# AEP, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# NXPI, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# ABNB, start 2020-12-10 , end 2023-03-31 total 580 records
#
# BIIB, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# ADSK, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# MCHP, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# IDXX, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# PDD, start 2018-07-26 , end 2023-03-31 total 1179 records
#
# CPRT, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# EXC, start 2012-01-03 , end 2023-03-31 total 2829 records
#
# PAYX, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# WDAY, start 2012-10-12 , end 2023-03-31 total 2633 records
#
# PCAR, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# MRVL, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# XEL, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# SGEN, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# ROST, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# DLTR, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# EA, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# VRSK, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# ODFL, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# CTSH, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# ILMN, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# FAST, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# CSGP, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# WBD, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# GFS, start 2021-10-28 , end 2023-03-31 total 358 records
#
# CRWD, start 2019-06-12 , end 2023-03-31 total 959 records
#
# BKR, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# WBA, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# DDOG, start 2019-09-19 , end 2023-03-31 total 890 records
#
# CEG, start 2022-01-19 , end 2023-03-31 total 302 records
#
# ANSS, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# EBAY, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# FANG, start 2012-10-12 , end 2023-03-31 total 2633 records
#
# ENPH, start 2012-03-30 , end 2023-03-31 total 2769 records
#
# ALGN, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# TEAM, start 2015-12-09 , end 2023-03-31 total 1840 records
#
# JD, start 2014-05-22 , end 2023-03-31 total 2231 records
#
# ZS, start 2018-03-16 , end 2023-03-31 total 1270 records
#
# ZM, start 2019-04-18 , end 2023-03-31 total 996 records
#
# SIRI, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# LCID, start 2020-09-18 , end 2023-03-31 total 638 records
#
# RIVN, start 2021-11-10 , end 2023-03-31 total 349 records
#
# SVXY, start 2012-01-03 , end 2023-03-31 total 2830 records
#
# MSFT 62
#
# AAPL 23
#
# AMZN 39
#
# NVDA 107
#
# GOOGL 63
#
# GOOG 63
#
# META 3
#
# TSLA 89
#
# AVGO 19
#
# PEP 58
#
# COST 35
#
# CSCO 88
#
# TMUS 102
#
# CMCSA 5
#
# AMD 31
#
# ADBE 33
#
# NFLX 49
#
# TXN 93
#
# HON 98
#
# SBUX 42
#
# INTU 43
#
# AMGN 39
#
# INTC 72
#
# QCOM 62
#
# ISRG 69
#
# AMAT 87
#
# MDLZ 55
#
# BKNG 10
#
# GILD 10
#
# ADI 83
#
# ADP 73
#
# VRTX 7
#
# REGN 2
#
# LRCX 88
#
# FISV 11
#
# MU 81
#
# PYPL 138
#
# MELI 93
#
# CSX 107
#
# MNST 45
#
# ATVI 98
#
# ASML 29
#
# ORLY 49
#
# PANW 119
#
# KLAC 108
#
# SNPS 30
#
# CDNS 53
#
# MAR 5
#
# FTNT 68
#
# CHTR 26
#
# MRNA 82
#
# KHC 92
#
# CTAS 40
#
# DXCM 25
#
# LULU 2
#
# KDP 34
#
# AZN 77
#
# AEP 62
#
# NXPI 6
#
# ABNB 78
#
# BIIB 16
#
# ADSK 70
#
# MCHP 95
#
# IDXX 39
#
# PDD 53
#
# CPRT 41
#
# EXC 38
#
# PAYX 75
#
# WDAY 48
#
# PCAR 76
#
# MRVL 41
#
# XEL 61
#
# SGEN 19
#
# ROST 8
#
# DLTR 55
#
# EA 6
#
# VRSK 12
#
# ODFL 62
#
# CTSH 71
#
# ILMN 3
#
# FAST 88
#
# CSGP 40
#
# WBD 17
#
# GFS 55
#
# CRWD 75
#
# BKR 58
#
# WBA 88
#
# DDOG 77
#
# CEG 13
#
# ANSS 48
#
# EBAY 13
#
# FANG 22
#
# ENPH 52
#
# ALGN 45
#
# TEAM 34
#
# JD 4
#
# ZS 41
#
# ZM 28
#
# SIRI 31
#
# LCID 7
#
# RIVN 13
#
# SVXY 6
